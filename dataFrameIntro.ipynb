# %% [markdown]
# dataframe by using csv file

# %%
import pandas as pd
df = pd.read_csv("./weather_prediction_dataset.csv")
df
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %% [markdown]
# dataframe by using dict

# %%
weather_data = {
    'date': ['1/1/2023', '2/3/2023', '1/3/2023','14/3/2023', '24/3/2023'],
    'temperature' : [32, 35, 39, 40,30],
    'windSpeed' : [6, 7, 4, 2, 1],
    'event': ['Rain', 'Sunny', 'Humid', 'cloudy', 'Snow']
}

df2 = pd.DataFrame(weather_data)
df2
# Out:
#         date  temperature  windSpeed   event
# 0   1/1/2023           32          6    Rain
# 1   2/3/2023           35          7   Sunny
# 2   1/3/2023           39          4   Humid
# 3  14/3/2023           40          2  cloudy
# 4  24/3/2023           30          1    Snow

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# ...

# %%
df.head(10)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
# 5  20000106      1                  3            0.85          1.0244
# 6  20000107      1                  8            0.84          1.0267
# 7  20000108      1                  4            0.79          1.0248
# 8  20000109      1                  8            0.88          1.0243
# 9  20000110      1                  8            0.91          1.0337
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# ...

# %%
rows, colums = df2.shape

# %%
colums
# Out:
# 4

# %%
rows
# Out:
# 5

# %%
df.tail(10)
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3644  20091223     12                  8            0.93          0.9984
# 3645  20091224     12                  8            0.93          0.9924
# 3646  20091225     12                  6            0.71          1.0025
# 3647  20091226     12                  4            0.81          1.0120
# 3648  20091227     12                  7            0.80          1.0118
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3644                    0.36                 0.61             1.1
# ...

# %%
df2[2:5]
# Out:
#         date  temperature  windSpeed   event
# 2   1/3/2023           39          4   Humid
# 3  14/3/2023           40          2  cloudy
# 4  24/3/2023           30          1    Snow

# %%
df2.columns
# Out:
# Index(['date', 'temperature', 'windSpeed', 'event'], dtype='object')

# %%
df2['event'] #df.event
# Out:
# 0      Rain
# 1     Sunny
# 2     Humid
# 3    cloudy
# 4      Snow
# Name: event, dtype: object

# %% [markdown]
# the col in a data frame is of type pandas.core.series

# %%
type(df2['event'])
# Out:
# pandas.core.series.Series

# %%
df2[['date', 'event', 'temperature']]
# Out:
#         date   event  temperature
# 0   1/1/2023    Rain           32
# 1   2/3/2023   Sunny           35
# 2   1/3/2023   Humid           39
# 3  14/3/2023  cloudy           40
# 4  24/3/2023    Snow           30

# %% [markdown]
# If we wanna do arithmetic op on data

# %%
df2['temperature'].max()
# Out:
# 40

# %%
df2['temperature'].mean()
# Out:
# 35.2

# %%
df2.describe() # desrcribe whole stats
# Out:
#        temperature  windSpeed
# count      5.00000    5.00000
# mean      35.20000    4.00000
# std        4.32435    2.54951
# min       30.00000    1.00000
# 25%       32.00000    2.00000
# 50%       35.00000    4.00000
# 75%       39.00000    6.00000
# max       40.00000    7.00000

# %%
df2[df2.temperature > 32]
# Out:
#         date  temperature  windSpeed   event
# 1   2/3/2023           35          7   Sunny
# 2   1/3/2023           39          4   Humid
# 3  14/3/2023           40          2  cloudy

# %%
df2[df2.temperature == df2['temperature'].max()]
# Out:
#         date  temperature  windSpeed   event
# 3  14/3/2023           40          2  cloudy

# %% [markdown]
# lets we just wanna max temp date and temperature

# %%
df2[['date', 'temperature']][df2.temperature == df2['temperature'].max()]
# Out:
#         date  temperature
# 3  14/3/2023           40

# %%
df2.index # here 5 is not included
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df2.set_index('date')
# Out:
#            temperature  windSpeed   event
# date
# 1/1/2023            32          6    Rain
# 2/3/2023            35          7   Sunny
# 1/3/2023            39          4   Humid
# 14/3/2023           40          2  cloudy
# 24/3/2023           30          1    Snow

# %%
df2
# Out:
#         date  temperature  windSpeed   event
# 0   1/1/2023           32          6    Rain
# 1   2/3/2023           35          7   Sunny
# 2   1/3/2023           39          4   Humid
# 3  14/3/2023           40          2  cloudy
# 4  24/3/2023           30          1    Snow

# %% [markdown]
# the data frame has changed

# %%
df2.loc['1/1/2023']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df2.loc['1/1/2023']
#
# File c:\Users\sahuj\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\sahuj\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File c:\Users\sahuj\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
# ...

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#         date  temperature  windSpeed   event
# 0   1/1/2023           32          6    Rain
# 1   2/3/2023           35          7   Sunny
# 2   1/3/2023           39          4   Humid
# 3  14/3/2023           40          2  cloudy
# 4  24/3/2023           30          1    Snow
